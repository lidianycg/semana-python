# %%
# !pip install pyautogui
# Out:
# Requirement already satisfied: pyautogui in c:\users\lidia\anaconda3\lib\site-packages (0.9.54)
# Requirement already satisfied: pytweening>=1.0.4 in c:\users\lidia\anaconda3\lib\site-packages (from pyautogui) (1.0.7)
# Requirement already satisfied: mouseinfo in c:\users\lidia\anaconda3\lib\site-packages (from pyautogui) (0.1.3)
# Requirement already satisfied: pymsgbox in c:\users\lidia\anaconda3\lib\site-packages (from pyautogui) (1.0.9)
# Requirement already satisfied: pyscreeze>=0.1.21 in c:\users\lidia\anaconda3\lib\site-packages (from pyautogui) (0.1.29)
# Requirement already satisfied: pygetwindow>=0.0.5 in c:\users\lidia\anaconda3\lib\site-packages (from pyautogui) (0.0.9)
# Requirement already satisfied: pyrect in c:\users\lidia\anaconda3\lib\site-packages (from pygetwindow>=0.0.5->pyautogui) (0.2.0)
# Requirement already satisfied: Pillow>=9.2.0 in c:\users\lidia\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (9.4.0)
# Requirement already satisfied: pyscreenshot in c:\users\lidia\anaconda3\lib\site-packages (from pyscreeze>=0.1.21->pyautogui) (3.1)
# Requirement already satisfied: pyperclip in c:\users\lidia\anaconda3\lib\site-packages (from mouseinfo->pyautogui) (1.8.2)
# Requirement already satisfied: mss in c:\users\lidia\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (9.0.1)
# Requirement already satisfied: EasyProcess in c:\users\lidia\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)
# Requirement already satisfied: entrypoint2 in c:\users\lidia\anaconda3\lib\site-packages (from pyscreenshot->pyscreeze>=0.1.21->pyautogui) (1.1)

# %%
# !pip install pyperclip
# Out:
# Requirement already satisfied: pyperclip in c:\users\lidia\anaconda3\lib\site-packages (1.8.2)

# %%
import yfinance as yf
import pyautogui
import pyperclip


ticker = input("Digite o código da ação: ")
dados = yf.Ticker(ticker).history("6mo")
fechamento = dados.Close

fechamento.plot()
maxima = round(fechamento.max(), 2)
minima = round(fechamento.min(), 2)
atual = round(fechamento[-1], 2)

print(maxima)
print(minima)
print(atual)


pyautogui.PAUSE = 4

pyautogui.hotkey("ctrl", "t")

pyperclip.copy("www.gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("enter")

pyautogui.click(x=-1129, y=94)

pyperclip.copy("lidiaany.caetano@gmail.com")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

pyperclip.copy("Análises diárias")
pyautogui.hotkey("ctrl", "v")
pyautogui.hotkey("tab")

mensagem = f"""
Prezado gestor, 
Seguem, conforme solicitado, as análises dos últimos seis meses da ação {ticker}:
Cotação máxima: R$ {maxima}
Cotação mínima: R$ {minima}
Cotação atual: R$ {atual}

Qualquer dúvida, fico à disposição!

Att,
Lidiany
"""

pyperclip.copy(mensagem)
pyautogui.hotkey("ctrl", "v")
pyautogui.click(x=-624, y=840)
print("E-mail enviado com sucesso!")
# Out:
# Digite o código da ação: ENJU3.SA
# 1.3
# 0.71
# 1.3
# E-mail enviado com sucesso!

# %%
import time

time.sleep(5)
pyautogui.position()
# Out:
# Point(x=-1129, y=94)
